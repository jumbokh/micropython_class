# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 在 [0, 2*PI] 之間取 100 個點
x = np.linspace(0, 2 * np.pi, num=100)

# %%
# 計算這 100 個點的正弦值，並保存到變數 y 中
y = np.sin(x)

# %%
# 畫出 x,y 即 正弦曲線
plt.plot(x,y)
